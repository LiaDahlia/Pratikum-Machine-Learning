# %% [markdown]
# <a href="https://colab.research.google.com/github/LiaDahlia/Pratikum-Machine-Learning/blob/main/Tugas_2_MachineLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
path_="/content/drive/My Drive/Machine Learning/pratikum-02.csv"
dataset=pd.read_csv(path_)
dataset
# Out:
#     Mileage  Age(yrs)  Sell Price($)
# 0     69000         6           1800
# 1     35000         3          34000
# 2     57000         5          26100
# 3     22500         2          40000
# 4     46000         4          31500
# 5     59000         5          26750
# 6     52000         5          32000
# 7     72000         6          19300
# 8     91000         8          12000
# 9     67000         6          22000
# 10    83000         7          18700
# 11    79000         7          19500
# 12    59000         5          26000
# 13    58780         4          27500
# 14    82450         7          19400
# 15    25400         3          35000
# 16    28000         2          35000
# 17    69000         5          19700
# 18    87600         8          12800
# 19    52000         5          28200

# %%
dataset.head()
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6           1800
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(dataset['Mileage'],dataset['Sell Price($)'])

# %%
plt.scatter(dataset['Age(yrs)'],dataset['Sell Price($)'])

# %%
X=dataset[['Mileage','Age(yrs)']]
y=dataset['Sell Price($)']
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5

# %%
y
# Out:
# 0      1800
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     26750
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    18700
# 11    19500
# 12    26000
# 13    27500
# 14    19400
# 15    35000
# 16    35000
# 17    19700
# 18    12800
# 19    28200
# Name: Sell Price($), dtype: int64

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 16

# %%
len(X_test)
# Out:
# 4

# %%
X_train
# Out:
#     Mileage  Age(yrs)
# 18    87600         8
# 11    79000         7
# 3     22500         2
# 15    25400         3
# 1     35000         3
# 7     72000         6
# 4     46000         4
# 9     67000         6
# 12    59000         5
# 13    58780         4
# 2     57000         5
# 10    83000         7
# 8     91000         8
# 5     59000         5
# 16    28000         2
# 6     52000         5

# %%
X_test
# Out:
#     Mileage  Age(yrs)
# 17    69000         5
# 0     69000         6
# 19    52000         5
# 14    82450         7

# %%
y_train
# Out:
# 18    12800
# 11    19500
# 3     40000
# 15    35000
# 1     34000
# 7     19300
# 4     31500
# 9     22000
# 12    26000
# 13    27500
# 2     26100
# 10    18700
# 8     12000
# 5     26750
# 16    35000
# 6     32000
# Name: Sell Price($), dtype: int64

# %%
y_test
# Out:
# 17    19700
# 0      1800
# 19    28200
# 14    19400
# Name: Sell Price($), dtype: int64

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2, random_state=10)
X
# Out:
#     Mileage  Age(yrs)
# 0     69000         6
# 1     35000         3
# 2     57000         5
# 3     22500         2
# 4     46000         4
# 5     59000         5
# 6     52000         5
# 7     72000         6
# 8     91000         8
# 9     67000         6
# 10    83000         7
# 11    79000         7
# 12    59000         5
# 13    58780         4
# 14    82450         7
# 15    25400         3
# 16    28000         2
# 17    69000         5
# 18    87600         8
# 19    52000         5
